# %%
import numpy as np
import pandas as pd
import os

from Data_getter import data_getter

# %%
YEARS = [2023]
CENSUS_API_KEY = os.getenv("CENSUS_API_KEY")

for year in YEARS:
    data_getter(
        year, 
        CENSUS_API_KEY, 
        variables=["Population_var", "StormDamage_var",
                    "MedianIncome_var", "HouseAge_var",
                    "ShorelineCounties_var", "WatershedCounties_var"]
    )
